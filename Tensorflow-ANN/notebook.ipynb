# %%
import tensorflow as tf

import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from tensorflow.examples.tutorials.mnist import input_data

mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
# Out:
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
data, labels = mnist.train.next_batch(1)

# %%
print data.shape
print labels.shape
# Out:
# (1, 784)
# (1, 10)

# %%
plt.imshow(data.reshape(28,28), cmap=plt.get_cmap('gray'))

# %%
tf.reset_default_graph()

x = tf.placeholder(tf.float32, [None, 784])

W = tf.Variable(tf.random_normal([784, 10]))
b = tf.Variable(tf.zeros([10]))

y = tf.nn.softmax(tf.nn.bias_add(tf.matmul(x, W), b))

# %%
tf.reset_default_graph()

num_neurons = 40

x = tf.placeholder(tf.float32, [None, 784])

W1 = tf.Variable(tf.random_normal([784, num_neurons]))
b1 = tf.Variable(tf.zeros([num_neurons]))

h1 = tf.nn.sigmoid(tf.nn.bias_add(tf.matmul(x, W1), b1))

W2 = tf.Variable(tf.random_normal([num_neurons, 10]))
b2 = tf.Variable(tf.zeros([10]))

y = tf.nn.softmax(tf.nn.bias_add(tf.matmul(h1, W2), b2))

# %%
from model import Model

# %%
model = Model()
model.build(x, y)
# Out:
# The model is ready! Create the model using the `build()` method.

# %%
s = model.train(mnist, 2000)
# Out:
# Run  100 	Training accuracy:  47.50% |   6.25% |  81.25%
# Run  200 	Training accuracy:  77.25% |  50.00% |  93.75%
# Run  300 	Training accuracy:  80.56% |  59.38% |  96.88%
# Run  400 	Training accuracy:  82.72% |  59.38% |  96.88%
# Run  500 	Training accuracy:  88.00% |  62.50% | 100.00%
# Run  600 	Training accuracy:  88.72% |  68.75% | 100.00%
# Run  700 	Training accuracy:  88.28% |  68.75% | 100.00%
# Run  800 	Training accuracy:  89.63% |  78.12% | 100.00%
# Run  900 	Training accuracy:  88.75% |  62.50% | 100.00%
# Run 1000 	Training accuracy:  91.25% |  78.12% | 100.00%
# Run 1100 	Training accuracy:  89.72% |  71.88% | 100.00%
# Run 1200 	Training accuracy:  90.75% |  78.12% | 100.00%
# Run 1300 	Training accuracy:  90.31% |  75.00% | 100.00%
# Run 1400 	Training accuracy:  90.97% |  75.00% | 100.00%
# Run 1500 	Training accuracy:  90.87% |  78.12% | 100.00%
# Run 1600 	Training accuracy:  92.12% |  78.12% | 100.00%
# Run 1700 	Training accuracy:  94.47% |  81.25% | 100.00%
# Run 1800 	Training accuracy:  93.25% |  81.25% | 100.00%
# Run 1900 	Training accuracy:  92.75% |  84.38% | 100.00%
# Run 2000 	Training accuracy:  92.78% |  81.25% | 100.00%
# Testing accuracy:  92.85%

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
W1_ = s.run(W1)
plt.imshow(W1_[:,0].reshape(28,28), cmap=plt.get_cmap('gray'))
